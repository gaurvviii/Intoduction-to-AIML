# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurvviii/Intoduction-to-AIML/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Region summary Australian Capital Territory STE 8.csv')

# %%
df.head ()
# Out:
#   Measure Code                                 Parent Description  \
# 0     ERP_P_20  Estimated resident population - year ended 30 ...
# 1       ERP_21  Estimated resident population - year ended 30 ...
# 2     ERP_M_20  Estimated resident population - year ended 30 ...
# 3     ERP_F_20  Estimated resident population - year ended 30 ...
# 4       ERP_19  Estimated resident population - year ended 30 ...
#
#                                      Description  2011  2015  2016      2017  \
# 0            Estimated resident population (no.)   NaN   NaN   NaN  416824.0
# 1               Population density (persons/km2)   NaN   NaN   NaN     176.8
# 2    Estimated resident population - males (no.)   NaN   NaN   NaN  206491.0
# 3  Estimated resident population - females (no.)   NaN   NaN   NaN  210333.0
# 4                     Median age - males (years)   NaN   NaN   NaN      34.1
#
#        2018      2019      2020      2021      2022
# 0  430140.0  441277.0  450632.0  453558.0  456692.0
# ...

# %%
df.tail(
)
# Out:
#     Measure Code                                 Parent Description  \
# 795    LTENURE_9  Land tenure experimental estimates - year ende...
# 796   LTENURE_10  Land tenure experimental estimates - year ende...
# 797   LTENURE_11  Land tenure experimental estimates - year ende...
# 798   LTENURE_12  Land tenure experimental estimates - year ende...
# 799   LTENURE_14  Land tenure experimental estimates - year ende...
#
#                           Description  2011  2015      2016  2017  2018  2019  \
# 795  Nature conservation reserve (ha)   NaN   NaN  144488.0   NaN   NaN   NaN
# 796   Multiple-use public forest (ha)   NaN   NaN   18669.0   NaN   NaN   NaN
# 797         Other Crown purposes (ha)   NaN   NaN   12406.0   NaN   NaN   NaN
# 798             Other Crown land (ha)   NaN   NaN    4344.0   NaN   NaN   NaN
# 799            Total land tenure (ha)   NaN   NaN  235962.0   NaN   NaN   NaN
#
#      2020  2021  2022
# 795   NaN   NaN   NaN
# 796   NaN   NaN   NaN
# ...

# %%
df.describe()
# Out:
#                 2011           2015           2016           2017  \
# count     235.000000      17.000000     520.000000     288.000000
# mean    14566.290213   28163.994118   21629.053483   28430.366674
# std     44478.061772   67344.897908   61443.511191   75617.748560
# min         0.100000       6.000000       0.000000       0.200000
# 25%         6.150000      67.500000       9.000000      28.975000
# 50%        55.200000    1431.000000      62.850000    3043.000000
# 75%      2288.500000    4700.000000    6554.750000   17396.500000
# max    313752.000000  235962.000000  605000.000000  645000.000000
#
#                 2018           2019           2020           2021  \
# count     332.000000     369.000000     312.000000     577.000000
# mean    26374.245765   23793.361764   25352.763077   17253.196118
# std     73398.929986   71627.659080   75766.807890   61780.746324
# min         0.190000    -194.000000    -650.000000   -3277.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Measure Code        800 non-null    object
#  1   Parent Description  800 non-null    object
#  2   Description         800 non-null    object
#  3   2011                235 non-null    float64
#  4   2015                17 non-null     float64
#  5   2016                520 non-null    float64
#  6   2017                288 non-null    float64
#  7   2018                332 non-null    float64
#  8   2019                369 non-null    float64
#  9   2020                312 non-null    float64
#  10  2021                577 non-null    float64
#  11  2022                97 non-null     float64
# dtypes: float64(9), object(3)
# memory usage: 75.1+ KB

# %%
df.iloc[:,5
        ]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 795    144488.0
# 796     18669.0
# 797     12406.0
# 798      4344.0
# 799    235962.0
# Name: 2016, Length: 800, dtype: float64

# %%
df['Description'].value_counts()
# Out:
# $3000 or more per week (%)               3
# $1-$499 per week (%)                     3
# Nil income (%)                           3
# Unemployed (no.)                         3
# Not in the labour force (%)              3
#                                         ..
# Construction (no.)                       1
# Wholesale trade (no.)                    1
# Retail trade (no.)                       1
# Accommodation and food services (no.)    1
# Total land tenure (ha)                   1
# Name: Description, Length: 753, dtype: int64

# %%
df.Description.unique()
# Out:
# array(['Estimated resident population (no.)',
#        'Population density (persons/km2)',
#        'Estimated resident population - males (no.)',
#        'Estimated resident population - females (no.)',
#        'Median age - males (years)', 'Median age - females (years)',
#        'Median age - persons (years)',
#        'Working age population (aged 15-64 years) (no.)',
#        'Working age population (aged 15-64 years) (%)',
#        'Males - 0-4 years (no.)', 'Males - 5-9 years (no.)',
#        'Males - 10-14 years (no.)', 'Males - 15-19 years (no.)',
#        'Males - 20-24 years (no.)', 'Males - 25-29 years (no.)',
#        'Males - 30-34 years (no.)', 'Males - 35-39 years (no.)',
#        'Males - 40-44 years (no.)', 'Males - 45-49 years (no.)',
#        'Males - 50-54 years (no.)', 'Males - 55-59 years (no.)',
#        'Males - 60-64 years (no.)', 'Males - 65-69 years (no.)',
#        'Males - 70-74 years (no.)', 'Males - 75-79 years (no.)',
# ...

# %%
sns.countplot(x ='Parent Description', data = df, palette = "husl")
# Out:
# <Axes: xlabel='Parent Description', ylabel='count'>

# %%
df.to_numpy()
# Out:
# array([['ERP_P_20', 'Estimated resident population - year ended 30 June',
#         'Estimated resident population (no.)', ..., 450632.0, 453558.0,
#         456692.0],
#        ['ERP_21', 'Estimated resident population - year ended 30 June',
#         'Population density (persons/km2)', ..., 191.1, 192.3, 193.7],
#        ['ERP_M_20', 'Estimated resident population - year ended 30 June',
#         'Estimated resident population - males (no.)', ..., 222636.0,
#         223867.0, nan],
#        ...,
#        ['LTENURE_11',
#         'Land tenure experimental estimates - year ended 30 June',
#         'Other Crown purposes (ha)', ..., nan, nan, nan],
#        ['LTENURE_12',
#         'Land tenure experimental estimates - year ended 30 June',
#         'Other Crown land (ha)', ..., nan, nan, nan],
#        ['LTENURE_14',
#         'Land tenure experimental estimates - year ended 30 June',
#         'Total land tenure (ha)', ..., nan, nan, nan]], dtype=object)

# %%
df.isnull()
# Out:
#      Measure Code  Parent Description  Description  2015   2016   2017   2018  \
# 0           False               False        False  True   True  False  False
# 1           False               False        False  True   True  False  False
# 2           False               False        False  True   True  False  False
# 3           False               False        False  True   True  False  False
# 4           False               False        False  True   True  False  False
# ..            ...                 ...          ...   ...    ...    ...    ...
# 795         False               False        False  True  False   True   True
# 796         False               False        False  True  False   True   True
# 797         False               False        False  True  False   True   True
# 798         False               False        False  True  False   True   True
# 799         False               False        False  True  False   True   True
#
#       2019   2020   2021   2022
# ...

# %%
df.isnull().sum()
# Out:
# Measure Code            0
# Parent Description      0
# Description             0
# 2015                  783
# 2016                  280
# 2017                  512
# 2018                  468
# 2019                  431
# 2020                  488
# 2021                  223
# 2022                  703
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-19-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           2015      2016      2017      2018      2019      2020      2021  \
# 2015  1.000000  0.999668  0.999986  0.995318  0.996822  0.988991       NaN
# 2016  0.999668  1.000000  0.999692  0.998672  0.998342  0.997048  0.997077
# 2017  0.999986  0.999692  1.000000  0.999562  0.999421  0.998904  0.997423
# 2018  0.995318  0.998672  0.999562  1.000000  0.999907  0.998882  0.998379
# 2019  0.996822  0.998342  0.999421  0.999907  1.000000  0.999221  0.998421
# 2020  0.988991  0.997048  0.998904  0.998882  0.999221  1.000000  0.998424
# 2021       NaN  0.997077  0.997423  0.998379  0.998421  0.998424  1.000000
# 2022       NaN       NaN  0.999507  0.999558  0.999690  0.999635  0.999727
#
#           2022
# 2015       NaN
# ...

# %%
plt.figure(figsize=(6,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-20-4db1e93d8da7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
cols = ['Measure Code',
        'Parent Description',
        'Description',
        '2017',
        '2021']

sns.pairplot(data=df[cols], hue='Parent Description', palette='rocket')

# %%
sns.histplot(df['2020'])
# Out:
# <Axes: xlabel='2020', ylabel='Count'>

# %%
sns.scatterplot(x = df['2018'],y = df['2019'])
# Out:
# <Axes: xlabel='2018', ylabel='2019'>

# %%
sns.lineplot(x = df['2019'],y = df['2020'])
# Out:
# <Axes: xlabel='2019', ylabel='2020'>
